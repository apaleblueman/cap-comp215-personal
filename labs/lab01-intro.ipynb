# %% [markdown]
# <a href="https://colab.research.google.com/github/apaleblueman/cap-comp215-personal/blob/main/labs/lab01-intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 1
# ----------------
# #### Name: Gurchetan Singh
# #### Date: 14 January 2024
#
# This lab exercise is mostly to introduce some of the power in Jupyter Notebooks.
# Note that a Notebook is composed of "cells" - some are "text", like this one, while others are "code"
#
# We'll also review some basic data types (like `int` and `str`) and data structures (like `list` and `dict`)
#
# **New Python Concepts**:
#   * `datetime.date` objects represent a calendar date (these are very powerful)
#   * *list comprehension* provides a compact way to represent map and filter algorithms
#
# As will be usual, the fist code cell, below, simply imports all the modules we'll be using...

# %%
import datetime, json, requests
import matplotlib.pyplot as plt
import  matplotlib.dates as mdates
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# ### API Query
#
# Now, let's fetch some Covid-19 daily case-count data from the Open Covid API:  https://opencovid.ca/api/
#
# Query:
#   - `stat=cases`        # the type of data to fetch
#   - `loc=BC`            # the location to fetch data for
#   - `after=2023-11-01`  # since the 1st of november (note date format:  yyyy-mm-dd)

# %%
query = 'https://api.opencovid.ca/timeseries?stat=cases&loc=BC&after=2023-11-01'

response = requests.request("GET", query, headers={}, data={})
print('Response data type:', type(response.text))
response.text[:1000]
# Out:
# Response data type: <class 'str'>
# ...

# %% [markdown]
# Notice that the response looks like a dictionary, but is actually just a string of text (most data is exchanged on the web as plain text!).  This particular data format is called "[JSON](https://en.wikipedia.org/wiki/JSON)"
#
# The `json.loads` function "parses" such text and loads the data into a dictionary...

# %%
result = json.loads(response.text)
pprint(result)   # pretty-print the entire data structure we got back...
# Out:
# {'data': {'cases': [{'date': '2023-11-01',
#                      'name': 'cases',
#                      'region': 'BC',
#                      'value': 410535,
#                      'value_daily': 91},
#                     {'date': '2023-11-02',
#                      'name': 'cases',
#                      'region': 'BC',
#                      'value': 410607,
#                      'value_daily': 72},
#                     {'date': '2023-11-03',
#                      'name': 'cases',
#                      'region': 'BC',
#                      'value': 410682,
#                      'value_daily': 75},
#                     {'date': '2023-11-04',
#                      'name': 'cases',
#                      'region': 'BC',
#                      'value': 410756,
#                      'value_daily': 74},
#                     {'date': '2023-11-05',
#                      'name': 'cases',
#                      'region': 'BC',
#                      'value': 410822,
# ...

# %% [markdown]
# ### Extract data items from a list of dictionaries
# Next we use "list comprehension" to extract the list of dates and associated cases into "parallel lists"
#
# Notice how we "parse" the date strings, using `strptime`, into a real date objects so they are easier to work with (format: yyyy-mm-dd)

# %%
cases = result['data']['cases']

case_dates = [daily['date'] for daily in cases]     # List Comprehension #1: extract the case date strings
n_cases = [daily['value_daily'] for daily in cases] # List Comprehension #2:  extract the case counts


print('Dates:', case_dates[:10])      # do you recall the "slice" operation?  If not, look it up in the ThinkCsPy textbook!
print('Cases:', n_cases[:10])
print('Zipped:', list(zip(case_dates[:10], n_cases[:10])))  # zip is a very handy function to "zip" 2 lists together like a zipper...
# Out:
# Dates: ['2023-11-01', '2023-11-02', '2023-11-03', '2023-11-04', '2023-11-05', '2023-11-06', '2023-11-07', '2023-11-08', '2023-11-09', '2023-11-10']
# Cases: [91, 72, 75, 74, 66, 93, 74, 66, 72, 57]
# Zipped: [('2023-11-01', 91), ('2023-11-02', 72), ('2023-11-03', 75), ('2023-11-04', 74), ('2023-11-05', 66), ('2023-11-06', 93), ('2023-11-07', 74), ('2023-11-08', 66), ('2023-11-09', 72), ('2023-11-10', 57)]

# %% [markdown]
# ### Datetime.date
# Working with date stings is a pain.  So many formats!  Even within Canada, you might see:
# "Jan. 9, 2023" or "09-01-2023" or "2023-01-09" or ....
# Imagine trying to do a calculation like "how many days between these 2 dates"!!
# The build-in `datetime` package makes working with dates much easier.
#   * step 1: "parse" the date string data (`strptime` ==  "string-parse-datetime object")
#   * step 2: get the date part (i.e., without the time)

# %%
# parse a datetime object from a string by supplying the correct "format" string.
datetime_objects = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in case_dates]  # List Comprehension #3

# but we only need the "date" part...
dates = [dt.date() for dt in datetime_objects]
dates[:10]
# Out:
# [datetime.date(2023, 11, 1),
#  datetime.date(2023, 11, 2),
#  datetime.date(2023, 11, 3),
#  datetime.date(2023, 11, 4),
#  datetime.date(2023, 11, 5),
#  datetime.date(2023, 11, 6),
#  datetime.date(2023, 11, 7),
#  datetime.date(2023, 11, 8),
#  datetime.date(2023, 11, 9),
#  datetime.date(2023, 11, 10)]

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, re-write each of the 3 "List Comprehensions" in the code cells above as a loop so you understand how they work.
#
# Notice that a "list comprehension" is a compact way to write a "list accumulator" algorithm (and more efficient too!)

# %%
# Ex. 1 your code here
#list1
date_list=[]
for index in cases:
  date_list.append(index['date'])
#list2
count_list = []
for index in cases:
  count_list.append(index['value_daily'])
#list3
formatted_dates = []
for index in date_list:
  index = datetime.datetime.strptime(index, '%Y-%m-%d')
  formatted_dates.append(index.date())

test_list = [date for date in formatted_dates]

test_list[:10]
# Out:
# [datetime.date(2023, 11, 1),
#  datetime.date(2023, 11, 2),
#  datetime.date(2023, 11, 3),
#  datetime.date(2023, 11, 4),
#  datetime.date(2023, 11, 5),
#  datetime.date(2023, 11, 6),
#  datetime.date(2023, 11, 7),
#  datetime.date(2023, 11, 8),
#  datetime.date(2023, 11, 9),
#  datetime.date(2023, 11, 10)]

# %% [markdown]
# ### Generating a plot
#
# Finally, we'll plot the (dates,cases) data as a nice x-y line graph.
#
# The code to format the x-axis labels is taken from https://matplotlib.org/stable/gallery/ticks/date_concise_formatter.html

# %%
def format_date_axis(ax):
  """ format the dates shown on the x-axis of given axes, ax  """
  locator = mdates.AutoDateLocator(minticks=10, maxticks=20)
  formatter = mdates.ConciseDateFormatter(locator)
  ax.xaxis.set_major_locator(locator)
  ax.xaxis.set_major_formatter(formatter)

fig, ax = plt.subplots()
format_date_axis(ax)
ax.plot(dates, n_cases, label='Daily Cases')  # Plot some data on the axes.
ax.set(
  title="Covid-19 case counts for BC",  # Add a title to the plot.
  xlabel='Date',                        # Add a label to X axes.
  ylabel='confirmed cases'             # Add a label to Y axes.
)
ax.legend();

# %% [markdown]
# ## Exercise 2
#
# Repeat the analysis above, but this time only for Vancouver Coastal Health Region.
#
# * Make a copy of just the relevant parts of the code above, leaving out all the explanations and extra data dumps.
# * You can get the ***hruid*** location code for each health region here:  https://github.com/ccodwg/CovidTimelineCanada/blob/main/geo/hr.csv
# * Generalize this code a little to make it easier to repeat the analysis for different locations.
#   If you get that working, also make it easy to run the analysis for different dates?

# %%
# Ex. 2 your code here
"""
  This was my first attempt for exercise 2
>Used chatGPT to understand how to manipulate URL parameter loc to provide Vancouver Coastal Health Region data only
>Then used openCovid API documentation[https://opencovid.ca/api/] (timeseries datatype) and
>github repository[https://github.com/ccodwg/CovidTimelineCanada#getting-started]  to understand how to request health region data
>example query for requesting Health Region data:  query= 'https://api.opencovid.ca/timeseries?stat=cases&geo=hr&hr_names=short&date=1'
>modified query to search health regions with hruid 593 of Vancouver Coastal Health Region
"""

VCH_query = 'https://api.opencovid.ca/timeseries?stat=cases&geo=hr&loc=593&after=2023-11-01'

#compared returned response with response on api website (URL tester which returned same response with HTTP code 200 succesfully) to check correct info
VCH_response = requests.request("GET", VCH_query, headers={}, data={}) #GET request to retrieve data in VCH_query URL; headers and data parameters are optional!
print(VCH_response) #should be 200

#since VCH_response is response object; we must convert it into text to pass it throgh json loads method

VCH_data = json.loads(VCH_response.text)
#pprint(VCH_data) #pretty printing the JSON data to make it more readable :3

#Now extracting all list data
VCH_cases = VCH_data['data']['cases']
VCH_daily_cases = [day['value_daily']  for day in VCH_cases]

VCH_dates = [current_day['date'] for current_day in VCH_cases]

#parsing dates to convert them to datetime objects
VCH_objs = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in VCH_dates]
#formatting objects to display date format only
final_dates = [date.date() for date in VCH_objs]


#plotting the graph using Matploit library
def format_date_axis(ax):
  """ format the dates shown on the x-axis of given axes, ax  """
  locator = mdates.AutoDateLocator(minticks=10, maxticks=20)
  formatter = mdates.ConciseDateFormatter(locator)
  ax.xaxis.set_major_locator(locator)
  ax.xaxis.set_major_formatter(formatter)

fig, ax = plt.subplots()
format_date_axis(ax)
ax.plot(final_dates, VCH_daily_cases, label='Daily Cases')  # Plot some data on the axes.

ax.set(
  title="Covid-19 case counts for Vancouver Health Region ",  # Add a title to the plot.
  xlabel='Date',                        # Add a label to X axes.
  ylabel='confirmed cases'             # Add a label to Y axes.
)
ax.legend();
# Out:
# <Response [200]>

# %%
#A generalised and function based version of exercise 2

def check_validity(loc_id, r_list):
      """Returns boolean value based on parameter validity"""
      if loc_id in r_list:
        return True
      else:
        return False

def format_date_axis(ax):
  """ format the dates shown on the x-axis of given axes, ax  """
  locator = mdates.AutoDateLocator(minticks=10, maxticks=20)
  formatter = mdates.ConciseDateFormatter(locator)
  ax.xaxis.set_major_locator(locator)
  ax.xaxis.set_major_formatter(formatter)

def get_region(loc_id):
    """Returns region name based of loc_id parameter; Returns False if parameter fails check_validity func"""
    query = "https://raw.githubusercontent.com/ccodwg/CovidTimelineCanada/main/geo/hr_wgs84.geojson"
    query_response = requests.request("GET", query, headers={}, data={})
    raw_hr_data = json.loads(query_response.text)
    regions_list = [data['properties']['name_canonical'] for data in raw_hr_data['features']] #used chatGPT to understand the hierarchical structure of the GeoJSON file.
    hruid_list = [data['properties']['hruid'] for data in raw_hr_data['features']]
    #make another list comprehension for hruids and zip the two together to form a tuple or dictionary which will be used to decide region of requested location id
    zipped_list  = list(zip(hruid_list,regions_list))
    region_dict = dict(zipped_list)
    if check_validity(loc_id,hruid_list):
      return region_dict[loc_id]
    else:
      return False
def graph_case_analysis(geo_lvl,location_id, initial_date, end_date):
  """graph the case analysis given geography level,location id and time period as parameters"""

  base_url = "https://api.opencovid.ca/timeseries?stat=cases"
  initial_date = datetime.datetime.strptime(initial_date, '%Y-%m-%d')
  end_date = datetime.datetime.strptime(end_date, '%Y-%m-%d')
  if(get_region(str(location_id)) and geo_lvl in ['hr','can','pt'] ):
    query = f'{base_url}&geo={geo_lvl}&loc={str(location_id)}&after={initial_date.date()}&before={end_date.date()}'

    response = requests.request("GET", query, headers={}, data={})
    raw_data = json.loads(response.text)
    # print(response) should be 200


    data = raw_data['data']['cases']

    daily_cases = [ case_num['value_daily']  for case_num  in data]
    raw_dates = [date['date'] for date in data]

    parsed_dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in raw_dates]
    # print(parsed_dates
    formatted_dates = [obj.date() for obj in parsed_dates]


    #graphing
    fig, ax = plt.subplots()
    format_date_axis(ax)
    ax.plot(parsed_dates, daily_cases, label='Daily Cases')  # Plot some data on the axes.

    ax.set(
      title=f"Covid-19 case counts for {get_region(str(location_id))} Region, BC from {initial_date.date()} to {end_date.date()}",  # Add a title to the plot.
      xlabel='Date',                        # Add a label to X axes.
      ylabel='confirmed cases'             # Add a label to Y axes.
    )
    ax.legend();
    #graphing average
    fig, ax = plt.subplots()
    format_date_axis(ax)
    rolling_dates = parsed_dates[6:] #since our window is 7 we need our dates to start from last day of every window;
                                     #This fixes Value error of dimensions of lists not matching
    ax.plot(rolling_dates, calc_avg(daily_cases,7), label='Weekly Rolling Average Cases')  # Plot some data on the axes.

    ax.set(
      title=f"Rolling Average of Covid-19 case counts for {get_region(str(location_id))} Region, BC from {initial_date.date()} to {end_date.date()} (7day rolling average)",  # Add a title to the plot.
      xlabel='Date',                        # Add a label to X axes.
      ylabel='confirmed cases'             # Add a label to Y axes.
    )
    ax.legend();



  else:
      print("Invalid loc or geo parameter(s)")




graph_case_analysis('hr', 594, '2023-11-01','2024-1-13')

# %% [markdown]
# ## Challenge Exercise - Take your skills to the next level...
#
# ## Exercise 3
#
# Notice that the data plot looks quite erratic.  These swings most likely represent artifacts attributable to the reporting process rather than actual changes in infection rates.
#
#  * One way to fix this is is to "smooth" the date with a "7-day rolling average".
# Each day, we take the average of the previous 7 days cases.
#  * Add new code cell below, compute the 7-day rolling average for each day from the cases list.
#  * Create a plot to display the rolling average data and compare your plot with the one produced above.
#
#  Hints: you are free to do this however you like, but a quite elegant solution uses list comprehension, range, and slices

# %%
# Ex. 3 (challenge) your code here
#this function is implemented in exercise 2 instance
#please run this function and then
#please run all(Ctrl+f9) to see results in ex2
def calc_avg(clist,window_size):
  "Returns 7 elements rolling average given a list and window length"
  avg_list = [sum(clist[n : n + window_size])/window_size for n in range(len(clist)-window_size + 1)]
  return avg_list
